# %% [markdown]
# <a href="https://colab.research.google.com/github/Hjhirp/Face-Mask-Emotion-Classification/blob/main/Notebook/Dataset%20Creation/Mask_The_Face_Dataset_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone 'https://github.com/aqeelanwar/MaskTheFace.git'

# %%
# %cd '/content/drive/MyDrive/Face Mask Paper'
# Out:
# /content/drive/MyDrive/Face Mask Paper

# %%
# %cd 'MaskTheFace'
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace

# %%
# import zipfile
# with zipfile.ZipFile('/content/drive/MyDrive/Face Mask Paper/MaskTheFace/archive(1).zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets')

# %%
# !pip install dotmap==1.3.14

# %%
# !nvidia-smi
# Out:
# Sun Apr  3 17:40:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Face Mask Paper/MaskTheFace'

# %%
# %cd datasets/train
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets/train

# %%
list_  = os.listdir('happy')

# %%
list_ = list_[0:4000] #Happy had 7500 images so i removed images after 4000 to balance dataset

# %%
path = 'happy/'
for file_ in list_:
  x = os.path.join(path,file_)
  os.remove(x)

# %%
len(list_ )
# Out:
# 1510

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace

# %% [markdown]
# # Masking

# %%
# !python mask_the_face.py --path 'datasets/train/happy' --mask_type 'all' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: datasets/train/happy/Training_81464344.jpg
# Faces found:  1
# Processing: datasets/train/happy/Training_8148160.jpg
# Faces found:  0
# Processing: datasets/train/happy/Training_81487345.jpg
# Faces found:  1
# Processing: datasets/train/happy/Training_8150140.jpg
# Faces found:  1
# Processing: datasets/train/happy/Training_815036.jpg
# Faces found:  1
# Processing: datasets/train/happy/Training_81524078.jpg
# Faces found:  1
# ...

# %%
# !python mask_the_face.py --path 'datasets/test/happy' --mask_type 'all' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: datasets/test/happy/PrivateTest_8861456.jpg
# Faces found:  1
# Processing: datasets/test/happy/PrivateTest_88679070.jpg
# Faces found:  1
# Processing: datasets/test/happy/PrivateTest_88702693.jpg
# Faces found:  1
# Processing: datasets/test/happy/PrivateTest_88754073.jpg
# Faces found:  1
# Processing: datasets/test/happy/PrivateTest_88760955.jpg
# Faces found:  1
# Processing: datasets/test/happy/PrivateTest_88847900.jpg
# Faces found:  1
# ...

# %%
# !python mask_the_face.py --path 'datasets/train/angry' --mask_type 'all' --verbose --write_original_image
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing: datasets/train/angry/Training_66405499.jpg
# Faces found:  0
# Processing: datasets/train/angry/Training_6640570.jpg
# Faces found:  0
# Processing: datasets/train/angry/Training_66428782.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66436160.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_6644670.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66459361.jpg
# Faces found:  0
# Processing: datasets/train/angry/Training_66483319.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66532755.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66555113.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66574043.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66594006.jpg
# Faces found:  1
# Processing: datasets/train/angry/Training_66776613.jpg
# Faces found:  1
# ...

# %%
# !python mask_the_face.py --path 'datasets/test/angry' --mask_type 'all' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: datasets/test/angry/PrivateTest_10304478.jpg
# Faces found:  0
# Processing: datasets/test/angry/PrivateTest_1054527.jpg
# Faces found:  1
# Processing: datasets/test/angry/PrivateTest_10590091.jpg
# Faces found:  0
# Processing: datasets/test/angry/PrivateTest_1109992.jpg
# Faces found:  1
# Processing: datasets/test/angry/PrivateTest_11296953.jpg
# Faces found:  1
# Processing: datasets/test/angry/PrivateTest_12000629.jpg
# Faces found:  0
# ...

# %%
# !python mask_the_face.py --path 'datasets/train/disgust' --mask_type 'N95' --verbose --write_original_image

# %%
# !python mask_the_face.py --path 'datasets/train/neutral' --mask_type 'all' --verbose --write_original_image
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing: datasets/train/neutral/Training_53577073.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_5357811.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_5357952.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_53590006.jpg
# Faces found:  0
# Processing: datasets/train/neutral/Training_53595941.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_53596713.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_53608696.jpg
# Faces found:  0
# Processing: datasets/train/neutral/Training_53609127.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_53612056.jpg
# Faces found:  0
# Processing: datasets/train/neutral/Training_53636581.jpg
# Faces found:  0
# Processing: datasets/train/neutral/Training_53652991.jpg
# Faces found:  1
# Processing: datasets/train/neutral/Training_5367395.jpg
# Faces found:  0
# ...

# %%
# !python mask_the_face.py --path 'datasets/test/neutral' --mask_type 'all' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: datasets/test/neutral/PrivateTest_45232469.jpg
# Faces found:  1
# Processing: datasets/test/neutral/PrivateTest_45783533.jpg
# Faces found:  1
# Processing: datasets/test/neutral/PrivateTest_45911744.jpg
# Faces found:  1
# Processing: datasets/test/neutral/PrivateTest_46022583.jpg
# Faces found:  1
# Processing: datasets/test/neutral/PrivateTest_46037321.jpg
# Faces found:  1
# Processing: datasets/test/neutral/PrivateTest_46100504.jpg
# ...

# %%
# !python mask_the_face.py --path 'datasets/train/sad' --mask_type 'all' --verbose --write_original_image
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing: datasets/train/sad/Training_49940595.jpg
# Faces found:  0
# Processing: datasets/train/sad/Training_49956876.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_49967235.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50011665.jpg
# Faces found:  0
# Processing: datasets/train/sad/Training_5005592.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50102721.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50104811.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50135030.jpg
# Faces found:  0
# Processing: datasets/train/sad/Training_5014257.jpg
# Faces found:  0
# Processing: datasets/train/sad/Training_5015510.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50195029.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50217841.jpg
# Faces found:  1
# Processing: datasets/train/sad/Training_50220440.jpg
# Faces found:  1
# ...

# %%
# !python mask_the_face.py --path 'datasets/test/sad' --mask_type 'all' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: datasets/test/sad/PrivateTest_46496161.jpg
# Faces found:  1
# Processing: datasets/test/sad/PrivateTest_46864083.jpg
# Faces found:  0
# Processing: datasets/test/sad/PrivateTest_47048382.jpg
# Faces found:  0
# Processing: datasets/test/sad/PrivateTest_47084428.jpg
# Faces found:  0
# Processing: datasets/test/sad/PrivateTest_47129405.jpg
# Faces found:  0
# Processing: datasets/test/sad/PrivateTest_47186743.jpg
# Faces found:  0
# ...

# %%
# !python mask_the_face.py --path 'datasets/train/surprise' --mask_type 'all' --verbose --write_original_image
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing: datasets/train/surprise/Training_90260579.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90340109.jpg
# Faces found:  0
# Processing: datasets/train/surprise/Training_90347319.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90460996.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90519473.jpg
# Faces found:  0
# Processing: datasets/train/surprise/Training_90544840.jpg
# Faces found:  0
# Processing: datasets/train/surprise/Training_9059249.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90625118.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90678511.jpg
# Faces found:  0
# Processing: datasets/train/surprise/Training_90690092.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90709299.jpg
# Faces found:  1
# Processing: datasets/train/surprise/Training_90712913.jpg
# Faces found:  1
# ...

# %%
# !python mask_the_face.py --path 'datasets/test/surprise' --mask_type 'all' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: datasets/test/surprise/PrivateTest_10072988.jpg
# Faces found:  0
# Processing: datasets/test/surprise/PrivateTest_10089743.jpg
# Faces found:  1
# Processing: datasets/test/surprise/PrivateTest_104142.jpg
# Faces found:  0
# Processing: datasets/test/surprise/PrivateTest_10427382.jpg
# Faces found:  1
# Processing: datasets/test/surprise/PrivateTest_10712253.jpg
# Faces found:  1
# Processing: datasets/test/surprise/PrivateTest_1076980.jpg
# ...

# %% [markdown]
# # Removing few image types

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace

# %%
# %cd datasets
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets

# %%
# %cd test
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets/test

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets

# %%
# %cd sad_masked
# Out:
# [Errno 2] No such file or directory: 'sad_masked'
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets

# %%
# !ls
# Out:
# download_links.txt  test  train

# %%
import os

# %%
list_ = os.listdir('surprise_masked')

# %%
list_[0:10]
# Out:
# ['Training_2898900_cloth.jpg',
#  'Training_2898900_gas.jpg',
#  'Training_2898900_KN95.jpg',
#  'Training_2898900_empty.jpg',
#  'Training_2898900_inpaint.jpg',
#  'Training_29088753_surgical.jpg',
#  'Training_29088753_surgical_green.jpg',
#  'Training_29088753_surgical_blue.jpg',
#  'Training_29088753_N95.jpg',
#  'Training_29088753_cloth.jpg']

# %%
head_path= 'surprise_masked/'

# %%
for i in list_:
  if i.endswith('inpaint.jpg'):
    x = os.path.join(head_path,i)
    os.remove(x)

# %%
for i in list_:
  if i.endswith('empty.jpg'):
    x = os.path.join(head_path,i)
    os.remove(x)

# %%
for i in list_:
  if i.endswith('gas.jpg'):
    x = os.path.join(head_path,i)
    os.remove(x)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets/train

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Face Mask Paper/MaskTheFace/datasets

# %% [markdown]
# #Extra -- no use now

# %%
list_ = os.listdir('train')

# %%
os.mkdir('data_2')

# %%
source = 'train/'
dest = 'data_2/'

# %%
# %cd data_2

# %%
import shutil
for i in list_:
  if i.endswith('_masked'):
    # s = os.path.join(source,i)
    # shutil.copytree(s,dest)
    os.mkdir(i)

# %%
# %cd ..

# %%
for i in list_:
  if i.endswith('_masked'):
    s = os.path.join(source,i)
    d = os.path.join(dest,i)
    list__ = os.listdir(s)
    for j in list__:
      x= os.path.join(s,j)
      shutil.move(x,d)
    print(i+' done')

# %%
# %cd data_2

# %%
list__ = os.listdir('happy_masked')
for i in list__ :
  x = os.path.join('happy_masked',i)
  os.remove(x)

# %%
# %cd ..

# %%
os.rmdir('happy_masked')

# %%
# list_ = os.listdir('/content/drive/MyDrive/Face Mask Paper/MaskTheFace/train')
# root_path = '/content/drive/MyDrive/Face Mask Paper/MaskTheFace/train'

# for i in list_:
#   path = os.path.join(root_path,i)
#   print(path)
#   !python mask_the_face.py --path path --mask_type 'all' --verbose --write_original_image
